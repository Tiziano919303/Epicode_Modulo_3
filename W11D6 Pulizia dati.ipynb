# %%
#Esercizio: lavoro sulla tabella DimProduct del db 'adventureworks' importato da SQL

#Installo la connessione Anaconda-MySQL
# !pip install sqlalchemy pymysql

# %%
from sqlalchemy import create_engine    #Connetto Anaconda-MySQL

# Sintassi: 'mysql+pymysql://user:password@host:port/database'
engine = create_engine('mysql+pymysql://root:FlAuTi919303@localhost:3306/adventureworks')

# %%
import pandas as pd    #Importo Pandas e cerco le colonne della tabella DimProduct + le prime 5 righe di ciascuna.

query = "SELECT * FROM DimProduct LIMIT 10;"
df = pd.read_sql(query, engine)

print(df.head())
# Out:
#    ProductKey ProductAlternateKey ProductSubcategoryKey WeightUnitMeasureCode  \
# 0           1             AR-5381                  None                  None
# 1           2             BA-8327                  None                  None
# 2           3             BE-2349                  None                  None
# 3           4             BE-2908                  None                  None
# 4           5             BL-2036                  None                  None
#
#   SizeUnitMeasureCode     EnglishProductName SpanishProductName  \
# 0                None        Adjustable Race
# 1                None           Bearing Ball
# 2                None        BB Ball Bearing
# 3                None  Headset Ball Bearings
# 4                None                  Blade
#
#   FrenchProductName StandardCost  FinishedGoodsFlag  ... ChineseDescription  \
# 0                           None                  0  ...               None
# ...

# %%
df = pd.read_sql("SELECT * FROM DimProduct", engine)    #Estraggo DimProduct
print(df.columns)    #Controllo se esiste la colonna DealerPrice su cui devo lavorare (esiste)
# Out:
# Index(['ProductKey', 'ProductAlternateKey', 'ProductSubcategoryKey',
#        'WeightUnitMeasureCode', 'SizeUnitMeasureCode', 'EnglishProductName',
#        'SpanishProductName', 'FrenchProductName', 'StandardCost',
#        'FinishedGoodsFlag', 'Color', 'SafetyStockLevel', 'ReorderPoint',
#        'ListPrice', 'Size', 'SizeRange', 'Weight', 'DaysToManufacture',
#        'ProductLine', 'DealerPrice', 'Class', 'Style', 'ModelName',
#        'LargePhoto', 'EnglishDescription', 'FrenchDescription',
#        'ChineseDescription', 'ArabicDescription', 'HebrewDescription',
#        'ThaiDescription', 'GermanDescription', 'JapaneseDescription',
#        'TurkishDescription', 'StartDate', 'EndDate', 'Status'],
#       dtype='object')

# %%
df['DealerPrice_2dec'] = df['DealerPrice'].round(2)    #Arrotondo i valori a due cifre decimali
df['DealerPrice_int'] = df['DealerPrice'].round(0).astype('Int64')  #Arrotondo all'intero più vicino (uso 'Int64' per supportare i NaN)
df['DealerPrice_clipped'] = df['DealerPrice'].clip(lower=0, upper=1000)    #Clippo per far comprendere i valori tra 0 e 1000
df[['DealerPrice', 'DealerPrice_2dec', 'DealerPrice_int', 'DealerPrice_clipped']].head()    #Mostro risultati

#Dall'output comprendo che almeno le prime 4 righe della colonna DealerPrice contengono solo valori nulli
# Out:
#    DealerPrice  DealerPrice_2dec  DealerPrice_int  DealerPrice_clipped
# 0          NaN               NaN             <NA>                  NaN
# 1          NaN               NaN             <NA>                  NaN
# 2          NaN               NaN             <NA>                  NaN
# 3          NaN               NaN             <NA>                  NaN
# 4          NaN               NaN             <NA>                  NaN

# %%
df[['DealerPrice']].dropna().head(10)    #Controllo se tutta la colonna contiene nulli ma scopro che non è così, perché
                                         #ci sono dati dalla riga 211 alla riga 220
# Out:
#      DealerPrice
# 211      20.1865
# 212      20.1865
# 213      20.9940
# 214      20.1865
# 215      20.1865
# 216      20.9940
# 217       5.7000
# 218       5.7000
# 219      20.1865
# 220      20.1865

# %%
#Esercizio: lavoro su un df dummy sintetico

#Creo il dataframe
import pandas as pd    #Importo pandas
import numpy as np    #Importo numpy

years = 5

guadagni = pd.DataFrame({
    "Mese": list("GFMAMGLASOND" * years),
    "Anno": np.repeat(list(range(years)), 12),
    "Valore": np.random.randint(800, 5000, 12 * years)
})

guadagni.head()
# Out:
#   Mese  Anno  Valore
# 0    G     0    2251
# 1    F     0    4284
# 2    M     0    4804
# 3    A     0    2184
# 4    M     0    1142

# %%
guadagni["Cumsum_totale"] = guadagni["Valore"].cumsum()    #Calcolo la somma cumulativa senza distinzione di anni
guadagni["Cumsum_per_anno"] = guadagni.groupby("Anno")["Valore"].cumsum()    #Calcolo la somma cumulativa per ogni anno
guadagni.head(15)   #Stampo la visualizzazione finale
# Out:
#    Mese  Anno  Valore  Cumsum_totale  Cumsum_per_anno  Somma_totale  \
# 0     G     0    2251           2251             2251          2251
# 1     F     0    4284           6535             6535          6535
# 2     M     0    4804          11339            11339         11339
# 3     A     0    2184          13523            13523         13523
# 4     M     0    1142          14665            14665         14665
# 5     G     0    1414          16079            16079         16079
# 6     L     0    1944          18023            18023         18023
# 7     A     0    2418          20441            20441         20441
# 8     S     0    4264          24705            24705         24705
# 9     O     0    2097          26802            26802         26802
# 10    N     0    1179          27981            27981         27981
# 11    D     0    2450          30431            30431         30431
# 12    G     1    3831          34262             3831         34262
# ...

# %%
#Esercizio: lavoro sulla tabella DimCustomer del db 'adventureworks' importato da SQL

#Importo la tabella DimCustomer
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine('mysql+pymysql://root:FlAuTi919303@localhost:3306/adventureworks')
df = pd.read_sql("SELECT * FROM DimCustomer", engine)
df.head()
# Out:
#    CustomerKey  GeographyKey CustomerAlternateKey Title  FirstName MiddleName  \
# 0        11000            26           AW00011000  None        Jon          V
# 1        11001            37           AW00011001  None     Eugene          L
# 2        11002            31           AW00011002  None      Ruben       None
# 3        11003            11           AW00011003  None    Christy       None
# 4        11004            19           AW00011004  None  Elizabeth       None
#
#   LastName  NameStyle   BirthDate MaritalStatus  ... EnglishOccupation  \
# 0     Yang          0  1971-10-06             M  ...      Professional
# 1    Huang          0  1976-05-10             S  ...      Professional
# 2   Torres          0  1971-02-09             M  ...      Professional
# 3      Zhu          0  1973-08-14             S  ...      Professional
# 4  Johnson          0  1979-08-05             S  ...      Professional
#
# ...

# %%
#Trasformo nomi in minuscolo e cognomi in maiuscolo
df["Nome_minusc"] = df["FirstName"].str.lower()
df["Cognome_maiusc"] = df["LastName"].str.upper()

#Estraggo nome utente e dominio dalla colonna 'EmailAddress'
df[["Nome_utente", "Dominio"]] = df["EmailAddress"].str.split("@", expand=True)

#Estraggo ogni parte del numero di telefono
df["Parti_numero"] = df["Phone"].str.split(" ")

#Estraggo le email che contengono "21"
df_21 = df[df["EmailAddress"].str.contains("21", na=False)]

# %%
#Visualizzo risultati e modifiche
df[["Nome_minusc", "Cognome_maiusc", 
    "Nome_utente", "Dominio", 
    "Parti_numero"]].head(11)
# Out:
#    Nome_minusc Cognome_maiusc  Nome_utente              Dominio  \
# 0          jon           YANG        jon24  adventure-works.com
# 1       eugene          HUANG     eugene10  adventure-works.com
# 2        ruben         TORRES      ruben35  adventure-works.com
# 3      christy            ZHU    christy12  adventure-works.com
# 4    elizabeth        JOHNSON   elizabeth5  adventure-works.com
# 5        julio           RUIZ       julio1  adventure-works.com
# 6        janet        ALVAREZ       janet9  adventure-works.com
# 7        marco          MEHTA      marco14  adventure-works.com
# 8          rob        VERHOFF         rob4  adventure-works.com
# 9      shannon        CARLSON    shannon38  adventure-works.com
# 10   jacquelyn         SUAREZ  jacquelyn20  adventure-works.com
#
#                 Parti_numero
# 0   [1, (11), 500, 555-0162]
# 1   [1, (11), 500, 555-0110]
# 2   [1, (11), 500, 555-0184]
# 3   [1, (11), 500, 555-0162]
# 4   [1, (11), 500, 555-0131]
# ...

# %%
#Estraggo le mail che contengono 10 o 20
email_20_10 = df[df["EmailAddress"].str.contains("20|10", na=False)]

#Calcolo lunghezze mail e trovo 5 più corte e 5 più lunghe
df["Lungh_mail"] = df["EmailAddress"].str.len()
email_piu_lunghe = df.nlargest(5, "Lungh_mail")[["EmailAddress", "Lungh_mail"]]
email_piu_corte  = df.nsmallest(5, "Lungh_mail")[["EmailAddress", "Lungh_mail"]]

#Sostituisco il dominio "adventure-works.com" con "aw-db.com"
df["Nuovo_dominio"] = df["EmailAddress"].str.replace("adventure-works.com", "aw-db.com")

#Estraggo indirizzo che contengono "Street" nella colonna "AddressLine1"
df_street = df[df["AddressLine1"].str.contains("Street", na=False)]

#Visualizzo risultati e modifiche
print("Email con '20' o '10':")
print(email_20_10[["EmailAddress"]].head())

print("\n5 email più lunghe:")
print(email_piu_lunghe)

print("\n5 email più corte:")
print(email_piu_corte)

print("\nNuovi domini:")
print(df["Nuovo_dominio"].head())

print("\nIndirizzi con 'Street':")
print(df_street[["AddressLine1"]].head())
# Out:
# Email con '20' o '10':
#                        EmailAddress
# 1      eugene10@adventure-works.com
# 10  jacquelyn20@adventure-works.com
# 22      ethan20@adventure-works.com
# 30    bethany10@adventure-works.com
# 32     denise10@adventure-works.com
#
# 5 email più lunghe:
#                            EmailAddress  Lungh_mail
# 979   christopher25@adventure-works.com          33
# 1767  christopher18@adventure-works.com          33
# 2655  christopher23@adventure-works.com          33
# 3512  christopher27@adventure-works.com          33
# 4772  christopher10@adventure-works.com          33
#
# 5 email più corte:
#                    EmailAddress  Lungh_mail
# 3974     k0@adventure-works.com          22
# 15299    y0@adventure-works.com          22
# 8      rob4@adventure-works.com          24
# 53     ana0@adventure-works.com          24
# 215    ana7@adventure-works.com          24
#
# Nuovi domini:
# 0         jon24@aw-db.com
# 1      eugene10@aw-db.com
# ...
